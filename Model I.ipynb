# %% [markdown]
# # FPL Player Points Forecast

# %%
#Import libraries

import requests
import pandas as pd
import numpy as np
import unicodedata

# %%
#Configure API

url = 'https://fantasy.premierleague.com/api/bootstrap-static/'

# %%
r = requests.get(url)

# %%
json = r.json()

# %%
json.keys()
# Out:
# dict_keys(['events', 'game_settings', 'phases', 'teams', 'total_players', 'elements', 'element_stats', 'element_types'])

# %% [markdown]
# # Extracting data needed

# %%
elements_df = pd.DataFrame(json['elements'])
elements_types_df = pd.DataFrame(json['element_types'])
teams_df = pd.DataFrame(json['teams'])

# %%
#List of all columns

elements_df.columns
# Out:
# Index(['chance_of_playing_next_round', 'chance_of_playing_this_round', 'code',
#        'cost_change_event', 'cost_change_event_fall', 'cost_change_start',
#        'cost_change_start_fall', 'dreamteam_count', 'element_type', 'ep_next',
#        'ep_this', 'event_points', 'first_name', 'form', 'id', 'in_dreamteam',
#        'news', 'news_added', 'now_cost', 'photo', 'points_per_game',
#        'second_name', 'selected_by_percent', 'special', 'squad_number',
#        'status', 'team', 'team_code', 'total_points', 'transfers_in',
#        'transfers_in_event', 'transfers_out', 'transfers_out_event',
#        'value_form', 'value_season', 'web_name', 'minutes', 'goals_scored',
#        'assists', 'clean_sheets', 'goals_conceded', 'own_goals',
#        'penalties_saved', 'penalties_missed', 'yellow_cards', 'red_cards',
#        'saves', 'bonus', 'bps', 'influence', 'creativity', 'threat',
#        'ict_index', 'influence_rank', 'influence_rank_type', 'creativity_rank',
#        'creativity_rank_type', 'threat_rank', 'threat_rank_type',
#        'ict_index_rank', 'ict_index_rank_type',
#        'corners_and_indirect_freekicks_order',
#        'corners_and_indirect_freekicks_text', 'direct_freekicks_order',
#        'direct_freekicks_text', 'penalties_order', 'penalties_text'],
#       dtype='object')

# %%
#Selecting columns wanted

slim_elements_df = elements_df[['first_name','second_name','team','element_type','selected_by_percent','now_cost','minutes','transfers_in','value_season','total_points']]

# %%
slim_elements_df.head()
# Out:
#        first_name           second_name  team  element_type  \
# 0           Mesut                  Özil     1             3
# 1        Sokratis      Papastathopoulos     1             2
# 2           David  Luiz Moreira Marinho     1             2
# 3  Pierre-Emerick            Aubameyang     1             3
# 4          Cédric                Soares     1             2
#
#   selected_by_percent  now_cost  minutes  transfers_in value_season  \
# 0                 0.7        68        0          3196          0.0
# 1                 0.1        49        0         10176          0.0
# 2                 1.1        55      271         25882          1.1
# 3                17.0       118      450        345268          1.5
# 4                 0.2        48        0          2318          0.0
#
#    total_points
# 0             0
# 1             0
# 2             6
# 3            18
# 4             0

# %%
slim_elements_df['position'] = slim_elements_df.element_type.map(elements_types_df.set_index('id').singular_name)
# Out:
# C:\Users\Conor\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
slim_elements_df.head()
# Out:
#        first_name           second_name  team  element_type  \
# 0           Mesut                  Özil     1             3
# 1        Sokratis      Papastathopoulos     1             2
# 2           David  Luiz Moreira Marinho     1             2
# 3  Pierre-Emerick            Aubameyang     1             3
# 4          Cédric                Soares     1             2
#
#   selected_by_percent  now_cost  minutes  transfers_in value_season  \
# 0                 0.7        68        0          3196          0.0
# 1                 0.1        49        0         10176          0.0
# 2                 1.1        55      271         25882          1.1
# 3                17.0       118      450        345268          1.5
# 4                 0.2        48        0          2318          0.0
#
#    total_points    position
# 0             0  Midfielder
# 1             0    Defender
# 2             6    Defender
# 3            18  Midfielder
# 4             0    Defender

# %%
slim_elements_df['team'] = slim_elements_df.team.map(teams_df.set_index('id').name)
# Out:
# C:\Users\Conor\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
slim_elements_df.head()
# Out:
#        first_name           second_name     team  element_type  \
# 0           Mesut                  Özil  Arsenal             3
# 1        Sokratis      Papastathopoulos  Arsenal             2
# 2           David  Luiz Moreira Marinho  Arsenal             2
# 3  Pierre-Emerick            Aubameyang  Arsenal             3
# 4          Cédric                Soares  Arsenal             2
#
#   selected_by_percent  now_cost  minutes  transfers_in value_season  \
# 0                 0.7        68        0          3196          0.0
# 1                 0.1        49        0         10176          0.0
# 2                 1.1        55      271         25882          1.1
# 3                17.0       118      450        345268          1.5
# 4                 0.2        48        0          2318          0.0
#
#    total_points    position
# 0             0  Midfielder
# 1             0    Defender
# 2             6    Defender
# 3            18  Midfielder
# 4             0    Defender

# %%
slim_elements_df['value'] = slim_elements_df.value_season.astype(float)
# Out:
# C:\Users\Conor\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
slim_elements_df.sort_values('value',ascending=False).tail(20)
# Out:
#        first_name         second_name       team  element_type  \
# 260         Filip            Benkovic  Leicester             2
# 291        Oliver               Casey      Leeds             2
# 314         Harry              Wilson  Liverpool             3
# 313        Divock               Origi  Liverpool             4
# 305          Alex  Oxlade-Chamberlain  Liverpool             3
# 304       Xherdan             Shaqiri  Liverpool             3
# 299  Konstantinos            Tsimikas  Liverpool             2
# 296         Diego            Llorente      Leeds             2
# 295       Mateusz              Bogusz      Leeds             3
# 1        Sokratis    Papastathopoulos    Arsenal             2
# 288        Jordan             Stevens      Leeds             3
# 284         Kamil              Miazek      Leeds             1
# 283       Jay-Roy                Grot      Leeds             3
# 275          Adam             Forshaw      Leeds             3
# 272         Barry             Douglas      Leeds             2
# 270     Francisco      Casilla Cortés      Leeds             1
# 263          Luke              Thomas  Leicester             2
# 587          Owen            Otasowie     Wolves             3
# 374          Eric              Bailly    Man Utd             2
# 504        Kieran               Gibbs  West Brom             2
#
#     selected_by_percent  now_cost  minutes  transfers_in value_season  \
# 260                 0.0        44        0           156          0.0
# 291                 0.7        40        0          8540          0.0
# 314                 0.0        52        0           419          0.0
# 313                 0.7        53        0         13871          0.0
# 305                 0.0        64        0           349          0.0
# 304                 0.1        64        0           737          0.0
# 299                 0.0        49        0           475          0.0
# 296                 0.0        45        0          2469          0.0
# 295                 0.0        45        0          1996          0.0
# 1                   0.1        49        0         10176          0.0
# 288                 0.7        44        0         16908          0.0
# 284                 1.7        40        0         21543          0.0
# 283                 0.0        48        0           772          0.0
# 275                 0.0        49        0           115          0.0
# 272                 7.5        39        0        141303          0.0
# 270                 1.2        43        0         12046          0.0
# 263                 0.2        43        0          4170          0.0
# 587                 0.0        45        0           159          0.0
# 374                 0.3        49       98          7994         -0.2
# 504                 0.3        44      135          4020         -0.7
#
#      total_points    position  value
# 260             0    Defender    0.0
# 291             0    Defender    0.0
# 314             0  Midfielder    0.0
# 313             0     Forward    0.0
# 305             0  Midfielder    0.0
# 304             0  Midfielder    0.0
# 299             0    Defender    0.0
# 296             0    Defender    0.0
# 295             0  Midfielder    0.0
# 1               0    Defender    0.0
# 288             0  Midfielder    0.0
# 284             0  Goalkeeper    0.0
# 283             0  Midfielder    0.0
# 275             0  Midfielder    0.0
# 272             0    Defender    0.0
# 270             0  Goalkeeper    0.0
# 263             0    Defender    0.0
# 587             0  Midfielder    0.0
# 374            -1    Defender   -0.2
# 504            -3    Defender   -0.7

# %%
model_elements_df = slim_elements_df[['first_name','second_name','team', 'position','selected_by_percent','now_cost','total_points']]

# %%
model_elements_df.head()
# Out:
#        first_name           second_name     team    position  \
# 0           Mesut                  Özil  Arsenal  Midfielder
# 1        Sokratis      Papastathopoulos  Arsenal    Defender
# 2           David  Luiz Moreira Marinho  Arsenal    Defender
# 3  Pierre-Emerick            Aubameyang  Arsenal  Midfielder
# 4          Cédric                Soares  Arsenal    Defender
#
#   selected_by_percent  now_cost  total_points
# 0                 0.7        68             0
# 1                 0.1        49             0
# 2                 1.1        55             6
# 3                17.0       118            18
# 4                 0.2        48             0

# %% [markdown]
# # Adding points to master dataframe

# %%
Points = {'position' : ['Goalkeeper', 'Defender', 'Midfielder', 'Forward'],
            'CS Points' : [4, 4, 1, 0],
             '1Goal Points' : [6, 6, 5, 4],
                '2Goal Points' : [12, 12, 10, 8]}

# %%
#Creating points dataframe

fullPoints = pd.DataFrame(Points, columns = ['position', 'CS Points', '1Goal Points', '2Goal Points'])
fullPoints
# Out:
#      position  CS Points  1Goal Points  2Goal Points
# 0  Goalkeeper          4             6            12
# 1    Defender          4             6            12
# 2  Midfielder          1             5            10
# 3     Forward          0             4             8

# %%
#Merging dataframes

inner_join = pd.merge(model_elements_df,
                     fullPoints,
                     on = 'position',
                     how = 'left')

inner_join
# Out:
#          first_name           second_name     team    position  \
# 0             Mesut                  Özil  Arsenal  Midfielder
# 1          Sokratis      Papastathopoulos  Arsenal    Defender
# 2             David  Luiz Moreira Marinho  Arsenal    Defender
# 3    Pierre-Emerick            Aubameyang  Arsenal  Midfielder
# 4            Cédric                Soares  Arsenal    Defender
# ..              ...                   ...      ...         ...
# 583         Ki-Jana                Hoever   Wolves    Defender
# 584          Nélson         Cabral Semedo   Wolves    Defender
# 585         Meritan               Shabani   Wolves  Midfielder
# 586           Rayan             Ait Nouri   Wolves    Defender
# 587            Owen              Otasowie   Wolves  Midfielder
#
#     selected_by_percent  now_cost  total_points  CS Points  1Goal Points  \
# 0                   0.7        68             0          1             5
# 1                   0.1        49             0          4             6
# 2                   1.1        55             6          4             6
# 3                  17.0       118            18          1             5
# 4                   0.2        48             0          4             6
# ..                  ...       ...           ...        ...           ...
# 583                 0.0        45             2          4             6
# 584                 2.1        55            13          4             6
# 585                 0.0        45             0          1             5
# 586                 0.0        50             0          4             6
# 587                 0.0        45             0          1             5
#
#      2Goal Points
# 0              10
# 1              12
# 2              12
# 3              10
# 4              12
# ..            ...
# 583            12
# 584            12
# 585            10
# 586            12
# 587            10
#
# [588 rows x 10 columns]

# %%
inner_join["Selection"] = inner_join["first_name"] + " " + inner_join["second_name"]
inner_join
# Out:
#          first_name           second_name     team    position  \
# 0             Mesut                  Özil  Arsenal  Midfielder
# 1          Sokratis      Papastathopoulos  Arsenal    Defender
# 2             David  Luiz Moreira Marinho  Arsenal    Defender
# 3    Pierre-Emerick            Aubameyang  Arsenal  Midfielder
# 4            Cédric                Soares  Arsenal    Defender
# ..              ...                   ...      ...         ...
# 583         Ki-Jana                Hoever   Wolves    Defender
# 584          Nélson         Cabral Semedo   Wolves    Defender
# 585         Meritan               Shabani   Wolves  Midfielder
# 586           Rayan             Ait Nouri   Wolves    Defender
# 587            Owen              Otasowie   Wolves  Midfielder
#
#     selected_by_percent  now_cost  total_points  CS Points  1Goal Points  \
# 0                   0.7        68             0          1             5
# 1                   0.1        49             0          4             6
# 2                   1.1        55             6          4             6
# 3                  17.0       118            18          1             5
# 4                   0.2        48             0          4             6
# ..                  ...       ...           ...        ...           ...
# 583                 0.0        45             2          4             6
# 584                 2.1        55            13          4             6
# 585                 0.0        45             0          1             5
# 586                 0.0        50             0          4             6
# 587                 0.0        45             0          1             5
#
#      2Goal Points                   Selection
# 0              10                  Mesut Özil
# 1              12   Sokratis Papastathopoulos
# 2              12  David Luiz Moreira Marinho
# 3              10   Pierre-Emerick Aubameyang
# 4              12               Cédric Soares
# ..            ...                         ...
# 583            12              Ki-Jana Hoever
# 584            12        Nélson Cabral Semedo
# 585            10             Meritan Shabani
# 586            12             Rayan Ait Nouri
# 587            10               Owen Otasowie
#
# [588 rows x 11 columns]

# %%
#Remove accents from names

inner_join = inner_join.replace({'Selection': {'ä' : 'a',
                                               'ä' : 'a',
                                               'â' : 'a',
                                               'á' : 'a',
                                               'ñ' : 'n',
                                               'Ñ' : 'N',
                                               'Ç' : 'C', 
                                               'ü' : 'u',
                                               'û' : 'u',
                                               'ù' : 'u',
                                               'ú' : 'u', 
                                               'ç' : 'c', 
                                               'é' : 'e',
                                               'ê' : 'e',
                                               'ë' : 'e',
                                               'è' : 'e',
                                               'ï' : 'i',
                                               'î' : 'i',
                                               'ì' : 'i',
                                               'í' : 'i',
                                               'ô' : 'o',
                                               'ö' : 'o',
                                               'ò' : 'o',
                                               'ó' : 'o',
                                               'Ö' : 'O'}}, regex=True)

# %%
inner_join = inner_join.replace({'Selection': {'Richarlison de Andrade' : 'Richarlison'}}, regex=True)

# %%
inner_join = inner_join.replace({'Selection': {'Heung-Min Son' : 'Son Heung-Min'}}, regex=True)

# %%
#Check if accents removed

inner_join[inner_join['Selection'].str.contains('Son')]
# Out:
#     first_name second_name   team    position selected_by_percent  now_cost  \
# 478  Heung-Min         Son  Spurs  Midfielder                51.6        94
#
#      total_points  CS Points  1Goal Points  2Goal Points      Selection
# 478            58          1             5            10  Son Heung-Min

# %% [markdown]
# # Processing odds data

# %%
#Reading in csv files for each game

anytime0 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\anytime0.csv')
anytime1 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\anytime1.csv')
anytime2 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\anytime2.csv')
anytime3 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\anytime3.csv')
anytime4 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\anytime4.csv')
anytime5 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\anytime5.csv')
anytime6 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\anytime6.csv')
anytime7 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\anytime7.csv')
anytime8 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\anytime8.csv')
anytime9 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\anytime9.csv')

#Anytime goalscorer odds dataframe

anytime = merged_df = pd.concat([anytime0,anytime1,anytime2,anytime3,anytime4,anytime5,anytime6,anytime7,anytime8,anytime9])

# %%
goals0 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\2goals0.csv')
goals1 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\2goals1.csv')
goals2 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\2goals2.csv')
goals3 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\2goals3.csv')
goals4 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\2goals4.csv')
goals5 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\2goals5.csv')
goals6 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\2goals6.csv')
goals7 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\2goals7.csv')
goals8 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\2goals8.csv')
goals9 = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\2goals9.csv')

#To score 2+ goals odds dataframe

goals = merged_df = pd.concat([goals0,goals1,goals2,goals3,goals4,goals5,goals6,goals7,goals8,goals9])

# %%
#Adding anytime goalscorer odds to master dataframe

new_table = pd.merge(inner_join,  
                      anytime,  
                      on ='Selection',  
                      how = 'inner')

# %%
#Adding score 2+ goal odds to master dataframe

new_table_2 = pd.merge(new_table,  
                      goals,  
                      on ='Selection',  
                      how = 'inner')

# %%
#Reading in cleansheet odds

cleansheetOdds = pd.read_csv(r'C:\Users\Conor\Documents\FPL\GW6\cleansheet6.csv')

# %%
#Adding clean sheet odds to master dataframe

final_table = pd.merge(new_table_2,  
                      cleansheetOdds,  
                      on ='team',  
                      how = 'inner')
final_table
# Out:
#          first_name second_name     team    position selected_by_percent  \
# 0    Pierre-Emerick  Aubameyang  Arsenal  Midfielder                17.0
# 1            Cédric      Soares  Arsenal    Defender                 0.2
# 2         Alexandre   Lacazette  Arsenal     Forward                 4.1
# 3            Granit       Xhaka  Arsenal  Midfielder                 0.6
# 4            Héctor    Bellerín  Arsenal    Defender                 5.8
# ..              ...         ...      ...         ...                 ...
# 293          Romain       Saïss   Wolves    Defender                17.4
# 294         Leander  Dendoncker   Wolves  Midfielder                 1.2
# 295           Adama      Traoré   Wolves  Midfielder                10.6
# 296           Oskar        Buur   Wolves    Defender                 2.6
# 297         Meritan     Shabani   Wolves  Midfielder                 0.0
#
#      now_cost  total_points  CS Points  1Goal Points  2Goal Points  \
# 0         118            18          1             5            10
# 1          48             0          4             6            12
# 2          85            22          0             4             8
# 3          54             9          1             5            10
# 4          50            20          4             6            12
# ..        ...           ...        ...           ...           ...
# 293        52            31          4             6            12
# 294        49            13          1             5            10
# 295        64             9          1             5            10
# 296        40             1          4             6            12
# 297        45             0          1             5            10
#
#                      Selection  Odds_x  Odds_y  odds
# 0    Pierre-Emerick Aubameyang    1.72     4.5  2.87
# 1                Cedric Soares   14.00   301.0  2.87
# 2          Alexandre Lacazette    2.30     7.5  2.87
# 3                 Granit Xhaka    9.00   126.0  2.87
# 4              Hector Bellerin   14.00   301.0  2.87
# ..                         ...     ...     ...   ...
# 293               Romain Saiss    9.50   126.0  2.10
# 294         Leander Dendoncker    7.50    91.0  2.10
# 295               Adama Traore    3.50    15.0  2.10
# 296                 Oskar Buur   18.00   301.0  2.10
# 297            Meritan Shabani    4.50    26.0  2.10
#
# [298 rows x 14 columns]

# %%
#Extracting columns needed

forecast = final_table[['Selection', 'team', 'position', 'selected_by_percent', 'now_cost', 'CS Points', '1Goal Points', '2Goal Points', 'Odds_x', 'Odds_y', 'odds']]

# %%
#Renaming columns

forecast.columns = ['Full Name', 'Team', 'Position', 'Ownership Percentage', 'Price', 'CS Points', '1 Goal Points', '2 Goal Points', 'Anytime Odds', '2 or More Odds', 'CS Odds']

# %%
forecast['Price'] = (forecast['Price'] / 10)
forecast
# Out:
# C:\Users\Conor\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                      Full Name     Team    Position Ownership Percentage  \
# 0    Pierre-Emerick Aubameyang  Arsenal  Midfielder                 17.0
# 1                Cedric Soares  Arsenal    Defender                  0.2
# 2          Alexandre Lacazette  Arsenal     Forward                  4.1
# 3                 Granit Xhaka  Arsenal  Midfielder                  0.6
# 4              Hector Bellerin  Arsenal    Defender                  5.8
# ..                         ...      ...         ...                  ...
# 293               Romain Saiss   Wolves    Defender                 17.4
# 294         Leander Dendoncker   Wolves  Midfielder                  1.2
# 295               Adama Traore   Wolves  Midfielder                 10.6
# 296                 Oskar Buur   Wolves    Defender                  2.6
# 297            Meritan Shabani   Wolves  Midfielder                  0.0
#
#      Price  CS Points  1 Goal Points  2 Goal Points  Anytime Odds  \
# 0     11.8          1              5             10          1.72
# 1      4.8          4              6             12         14.00
# 2      8.5          0              4              8          2.30
# 3      5.4          1              5             10          9.00
# 4      5.0          4              6             12         14.00
# ..     ...        ...            ...            ...           ...
# 293    5.2          4              6             12          9.50
# 294    4.9          1              5             10          7.50
# 295    6.4          1              5             10          3.50
# 296    4.0          4              6             12         18.00
# 297    4.5          1              5             10          4.50
#
#      2 or More Odds  CS Odds
# 0               4.5     2.87
# 1             301.0     2.87
# 2               7.5     2.87
# 3             126.0     2.87
# 4             301.0     2.87
# ..              ...      ...
# 293           126.0     2.10
# 294            91.0     2.10
# 295            15.0     2.10
# 296           301.0     2.10
# 297            26.0     2.10
#
# [298 rows x 11 columns]

# %%
#Deleting rows of missing players

indexNames = forecast[forecast['Anytime Odds'] == 1.0 ].index
forecast.drop(indexNames , inplace=True)
# Out:
# C:\Users\Conor\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#Deleting rows of missing players

indexNames = forecast[forecast['2 or More Odds'] == 1.0 ].index
forecast.drop(indexNames , inplace=True)

# %% [markdown]
# # Forecasting points

# %%
#Calculating probabilities based off of odds data

forecast['Cleansheet Probability'] = (1 / forecast['CS Odds']) 
forecast['1 Goal Probability'] = (1 / forecast['Anytime Odds'])
forecast['2 Goal Probability'] = (1 / forecast['2 or More Odds'])
# Out:
# C:\Users\Conor\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Conor\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#Calculating individual points per score type

forecast['Cleansheet Expected'] = forecast['Cleansheet Probability'] * forecast['CS Points']
forecast['Anytime Expected'] = forecast['1 Goal Probability'] * forecast['1 Goal Points']
forecast['2 Goal Expected'] = forecast['2 Goal Probability'] * forecast['2 Goal Points']

# %%
#Totalling all expected points

forecast['Total Forecasted Points'] = (forecast['Cleansheet Expected'] + forecast['Anytime Expected'] + forecast['2 Goal Expected'])

# %%
#Calculating 'Points Per Million'

forecast['PPM'] = forecast['Total Forecasted Points'] / forecast['Price']

# %%
#'Test' csv containing all columns

forecast.to_csv(r'C:\Users\Conor\Documents\FPL\GW6\test1.csv', index = False)

# %%
#Extracting final dataframe

finalForecast = forecast[['Full Name', 'Team', 'Position', 'Ownership Percentage', 'Price', 'Total Forecasted Points', 'PPM']]

# %%
finalForecast
# Out:
#                      Full Name     Team    Position Ownership Percentage  \
# 0    Pierre-Emerick Aubameyang  Arsenal  Midfielder                 17.0
# 1                Cedric Soares  Arsenal    Defender                  0.2
# 2          Alexandre Lacazette  Arsenal     Forward                  4.1
# 3                 Granit Xhaka  Arsenal  Midfielder                  0.6
# 4              Hector Bellerin  Arsenal    Defender                  5.8
# ..                         ...      ...         ...                  ...
# 293               Romain Saiss   Wolves    Defender                 17.4
# 294         Leander Dendoncker   Wolves  Midfielder                  1.2
# 295               Adama Traore   Wolves  Midfielder                 10.6
# 296                 Oskar Buur   Wolves    Defender                  2.6
# 297            Meritan Shabani   Wolves  Midfielder                  0.0
#
#      Price  Total Forecasted Points       PPM
# 0     11.8                 5.477631  0.464206
# 1      4.8                 1.862167  0.387951
# 2      8.5                 2.805797  0.330094
# 3      5.4                 0.983353  0.182102
# 4      5.0                 1.862167  0.372433
# ..     ...                      ...       ...
# 293    5.2                 2.631579  0.506073
# 294    4.9                 1.252747  0.255663
# 295    6.4                 2.571429  0.401786
# 296    4.0                 2.277962  0.569491
# 297    4.5                 1.971917  0.438204
#
# [298 rows x 7 columns]

# %%
#Final csv file with desired data

finalForecast.to_csv(r'C:\Users\Conor\Documents\FPL\GW6\GW6_forecast.csv', index = False)
